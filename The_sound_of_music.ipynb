# %% [markdown]
# For this project, we are going to analyze a music dataset I found interesting from kaggle.
#
# I did a little analysis after my last project and decided that planning each project going forward is better for me, so that I can bring out the best information from the datasets and use time effectively.
#
# I have also desided to use sql exclusively for data manipulation while using other python packages (eg. pandas, numpy etc.) for other data imvolved processes including data transformation in all my projects going forward.
#
# Possible goals we want to achieve with this dataset may include:
# + Know the most popular genre of music over the decade and how they changed with time.
# + Know the most popular artist in each genre if possible.
# + Know and quantify the rate of popularity/growth of a song track
# + Create a model to predict a person's favourite genre by analysing their music history.
# + create a model to predict if a song is going to be a hit or not.
# + predict if an artist is going to be popular or make it onto the top 100 billboard or something for a certain period of time preferably monthly.
#
# ##Update:
# From the third goal all the way to the last is completely unachievable with the dataset I found hence I will just focus on visualization for now.

# %% [markdown]
# ###A description of the dataset to be used.
#
# This dataset presents a comprehensive compilation of the most streamed songs on Spotify in 2024. It provides extensive insights into each track's attributes, popularity, and presence on various music platforms, offering a valuable resource for music analysts, enthusiasts, and industry professionals. The dataset includes information such as track name, artist, release date, ISRC, streaming statistics, and presence on platforms like YouTube, TikTok, and more.
#
# ###Key features of the dataset:
#
# + Track Name: Name of the song.
# + Album Name: Name of the album the song belongs to.
# + Artist: Name of the artist(s) of the song.
# + Release Date: Date when the song was released.
# + ISRC: International Standard Recording Code for the song.
# + All Time Rank: Ranking of the song based on its all-time popularity.
# + Track Score: Score assigned to the track based on various factors.
# + Spotify Streams: Total number of streams on Spotify.
# + Spotify Playlist Count: Number of Spotify playlists the song is included in.
# + Spotify Playlist Reach: Reach of the song across Spotify playlists.
# + Spotify Popularity: Popularity score of the song on Spotify.
# + YouTube Views: Total views of the song's official video on YouTube.
# + YouTube Likes: Total likes on the song's official video on YouTube.
# + TikTok Posts: Number of TikTok posts featuring the song.
# + TikTok Likes: Total likes on TikTok posts featuring the song.
# + TikTok Views: Total views on TikTok posts featuring the song.
# + YouTube Playlist Reach: Reach of the song across YouTube playlists.
# + Apple Music Playlist Count: Number of Apple Music playlists the song is included in.
# + AirPlay Spins: Number of times the song has been played on radio stations.
# + SiriusXM Spins: Number of times the song has been played on SiriusXM.
# + Deezer Playlist Count: Number of Deezer playlists the song is included in.
# + Deezer Playlist Reach: Reach of the song across Deezer playlists.
# + Amazon Playlist Count: Number of Amazon Music playlists the song is included in.
# + Pandora Streams: Total number of streams on Pandora.
# + Pandora Track Stations: Number of Pandora stations featuring the song.
# + Soundcloud Streams: Total number of streams on Soundcloud.
# + Shazam Counts: Total number of times the song has been Shazamed.
# + TIDAL Popularity: Popularity score of the song on TIDAL.
# + Explicit Track: Indicates whether the song contains explicit content.

# %% [markdown]
# ##Installing the required packages

# %%
# !pip install pandasql
from google.colab import drive
import pandas as pd
import numpy as np
import pandasql as psql
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# Requirement already satisfied: pandasql in /usr/local/lib/python3.10/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandasql) (2.1.4)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from pandasql) (2.0.32)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->pandasql) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->pandasql) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.16.0)

# %% [markdown]
# ##Connecting to my google drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Loading Dataset from googledrive

# %%
path = "/content/drive/MyDrive/projects/datasets/spotify.csv"
df = pd.read_csv(path, encoding='latin-1')
df1 = df.copy()
del df
df1.head(10)
# Out:
#                         Track                                    Album Name  \
# 0         MILLION DOLLAR BABY                  Million Dollar Baby - Single
# 1                 Not Like Us                                   Not Like Us
# 2  i like the way you kiss me                    I like the way you kiss me
# 3                     Flowers                              Flowers - Single
# 4                     Houdini                                       Houdini
# 5                 Lovin On Me                                   Lovin On Me
# 6            Beautiful Things                              Beautiful Things
# 7                   Gata Only                                     Gata Only
# 8        Danza Kuduro - Cover  ýýýýýýýýýýýýýýýýýýýýý - ýýýýýýýýýýýýýýýýýý -
# 9  BAND4BAND (feat. Lil Baby)                    BAND4BAND (feat. Lil Baby)
#
#            Artist Release Date          ISRC All Time Rank  Track Score  \
# 0   Tommy Richman    4/26/2024  QM24S2402528             1        725.4
# 1  Kendrick Lamar     5/4/2024  USUG12400910             2        545.9
# 2         Artemas    3/19/2024  QZJ842400387             3        538.4
# 3     Miley Cyrus    1/12/2023  USSM12209777             4        444.9
# 4          Eminem    5/31/2024  USUG12403398             5        423.3
# 5     Jack Harlow   11/10/2023  USAT22311371             6        410.1
# 6    Benson Boone    1/18/2024  USWB12307016             7        407.2
# 7      FloyyMenor     2/2/2024  QZL382406049             8        375.8
# 8   MUSIC LAB JPN     6/9/2024  TCJPA2463708             9        355.7
# 9     Central Cee    5/23/2024  USSM12404354            10        330.6
#
#   Spotify Streams Spotify Playlist Count Spotify Playlist Reach  \
# 0     390,470,936                 30,716            196,631,588
# 1     323,703,884                 28,113            174,597,137
# 2     601,309,283                 54,331            211,607,669
# 3   2,031,280,633                269,802            136,569,078
# 4     107,034,922                  7,223            151,469,874
# 5     670,665,438                105,892            175,421,034
# 6     900,158,751                 73,118            201,585,714
# 7     675,079,153                 40,094            211,236,940
# 8   1,653,018,119                      1                     15
# 9      90,676,573                 10,400            184,199,419
#
#    Spotify Popularity  YouTube Views YouTube Likes TikTok Posts  \
# 0                92.0     84,274,754     1,713,126    5,767,700
# 1                92.0    116,347,040     3,486,739      674,700
# 2                92.0    122,599,116     2,228,730    3,025,400
# 3                85.0  1,096,100,899    10,629,796    7,189,811
# 4                88.0     77,373,957     3,670,188       16,400
# 5                83.0    131,148,091     1,392,593    4,202,367
# 6                86.0    308,723,145     4,120,760          NaN
# 7                92.0    228,382,568     1,439,495    3,500,000
# 8                 NaN            NaN           NaN          NaN
# 9                86.0     32,735,244       988,682      325,800
#
#     TikTok Likes    TikTok Views YouTube Playlist Reach  \
# 0    651,565,900   5,332,281,936            150,597,040
# 1     35,223,547     208,339,025            156,380,351
# 2    275,154,237   3,369,120,610            373,784,955
# 3  1,078,757,968  14,603,725,994          3,351,188,582
# 4            NaN             NaN            112,763,851
# 5    214,943,489   2,938,686,633          2,867,222,632
# 6     29,584,940     534,915,313          4,601,579,812
# 7    338,546,668   3,804,584,163          2,112,581,620
# 8            NaN             NaN                    NaN
# 9    121,574,500     974,656,200            174,706,874
#
#    Apple Music Playlist Count AirPlay Spins SiriusXM Spins  \
# 0                       210.0        40,975            684
# 1                       188.0        40,778              3
# 2                       190.0        74,333            536
# 3                       394.0     1,474,799          2,182
# 4                       182.0        12,185              1
# 5                       138.0       522,042          4,654
# 6                       280.0       383,478            429
# 7                       160.0        17,221             30
# 8                         NaN           NaN            NaN
# 9                       191.0         3,823            117
#
#    Deezer Playlist Count Deezer Playlist Reach  Amazon Playlist Count  \
# 0                   62.0            17,598,718                  114.0
# 1                   67.0            10,422,430                  111.0
# 2                  136.0            36,321,847                  172.0
# 3                  264.0            24,684,248                  210.0
# 4                   82.0            17,660,624                  105.0
# 5                   86.0            17,167,254                  152.0
# 6                  168.0            48,197,850                  154.0
# 7                   87.0            33,245,595                   53.0
# 8                    NaN                   NaN                    NaN
# 9                   78.0            10,800,098                   92.0
#
#   Pandora Streams Pandora Track Stations Soundcloud Streams Shazam Counts  \
# 0      18,004,655                 22,931          4,818,457     2,669,262
# 1       7,780,028                 28,444          6,623,075     1,118,279
# 2       5,022,621                  5,639          7,208,651     5,285,340
# 3     190,260,277                203,384                NaN    11,822,942
# 4       4,493,884                  7,006            207,179       457,017
# 5     138,529,362                 50,982          9,438,601     4,517,131
# 6      65,447,476                 57,372                NaN     9,990,302
# 7       3,372,428                  5,762                NaN     6,063,523
# 8             NaN                    NaN                NaN           NaN
# 9       1,005,626                    842          3,679,709       666,302
#
#    TIDAL Popularity  Explicit Track  Explicit Classified
# 0               NaN               0                    0
# 1               NaN               1                    1
# 2               NaN               0                    1
# 3               NaN               0                    0
# 4               NaN               1                    1
# 5               NaN               1                    0
# 6               NaN               0                    0
# 7               NaN               1                    1
# 8               NaN               1                    0
# 9               NaN               1                    1

# %% [markdown]
# ##Set pandas to show all the columns in the dataset:

# %%
pd.set_option('display.max_columns', None)
df1.head(5)
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  \
# 0                 30,716            196,631,588                92.0
# 1                 28,113            174,597,137                92.0
# 2                 54,331            211,607,669                92.0
# 3                269,802            136,569,078                85.0
# 4                  7,223            151,469,874                88.0
#
#    YouTube Views YouTube Likes TikTok Posts   TikTok Likes    TikTok Views  \
# 0     84,274,754     1,713,126    5,767,700    651,565,900   5,332,281,936
# 1    116,347,040     3,486,739      674,700     35,223,547     208,339,025
# 2    122,599,116     2,228,730    3,025,400    275,154,237   3,369,120,610
# 3  1,096,100,899    10,629,796    7,189,811  1,078,757,968  14,603,725,994
# 4     77,373,957     3,670,188       16,400            NaN             NaN
#
#   YouTube Playlist Reach  Apple Music Playlist Count AirPlay Spins  \
# 0            150,597,040                       210.0        40,975
# 1            156,380,351                       188.0        40,778
# 2            373,784,955                       190.0        74,333
# 3          3,351,188,582                       394.0     1,474,799
# 4            112,763,851                       182.0        12,185
#
#   SiriusXM Spins  Deezer Playlist Count Deezer Playlist Reach  \
# 0            684                   62.0            17,598,718
# 1              3                   67.0            10,422,430
# 2            536                  136.0            36,321,847
# 3          2,182                  264.0            24,684,248
# 4              1                   82.0            17,660,624
#
#    Amazon Playlist Count Pandora Streams Pandora Track Stations  \
# 0                  114.0      18,004,655                 22,931
# 1                  111.0       7,780,028                 28,444
# 2                  172.0       5,022,621                  5,639
# 3                  210.0     190,260,277                203,384
# 4                  105.0       4,493,884                  7,006
#
#   Soundcloud Streams Shazam Counts  TIDAL Popularity  Explicit Track  \
# 0          4,818,457     2,669,262               NaN               0
# 1          6,623,075     1,118,279               NaN               1
# 2          7,208,651     5,285,340               NaN               0
# 3                NaN    11,822,942               NaN               0
# 4            207,179       457,017               NaN               1
#
#    Explicit Classified
# 0                    0
# 1                    1
# 2                    1
# 3                    0
# 4                    1

# %%
df1.shape
# Out:
# (4600, 30)

# %% [markdown]
# ##Analysing missing values

# %%
df1.info()
missing_values = df1.isnull().sum()
missing_values.name = 'missing_data'
missing_values = missing_values.reset_index()
missing_values.columns = ['columns', 'missing_data']
missing_values.missing_data = missing_values.missing_data.astype(int)
missing_values =missing_values.sort_values(by = 'missing_data', ascending = False)
missing_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
#  12  YouTube Likes               4285 non-null   object
#  13  TikTok Posts                3427 non-null   object
#  14  TikTok Likes                3620 non-null   object
#  15  TikTok Views                3619 non-null   object
#  16  YouTube Playlist Reach      3591 non-null   object
#  17  Apple Music Playlist Count  4039 non-null   float64
#  18  AirPlay Spins               4102 non-null   object
#  19  SiriusXM Spins              2477 non-null   object
#  20  Deezer Playlist Count       3679 non-null   float64
#  21  Deezer Playlist Reach       3672 non-null   object
#  22  Amazon Playlist Count       3545 non-null   float64
#  23  Pandora Streams             3494 non-null   object
#  24  Pandora Track Stations      3332 non-null   object
#  25  Soundcloud Streams          1267 non-null   object
#  26  Shazam Counts               4023 non-null   object
#  27  TIDAL Popularity            0 non-null      float64
#  28  Explicit Track              4600 non-null   int64
#  29  Explicit Classified         4600 non-null   int64
# dtypes: float64(6), int64(2), object(22)
# memory usage: 1.1+ MB
#                        columns  missing_data
# 27            TIDAL Popularity          4600
# 25          Soundcloud Streams          3333
# 19              SiriusXM Spins          2123
# 24      Pandora Track Stations          1268
# 13                TikTok Posts          1173
# 23             Pandora Streams          1106
# 22       Amazon Playlist Count          1055
# 16      YouTube Playlist Reach          1009
# 15                TikTok Views           981
# 14                TikTok Likes           980
# 21       Deezer Playlist Reach           928
# 20       Deezer Playlist Count           921
# 10          Spotify Popularity           804
# 26               Shazam Counts           577
# 17  Apple Music Playlist Count           561
# 18               AirPlay Spins           498
# 12               YouTube Likes           315
# 11               YouTube Views           308
# 7              Spotify Streams           113
# 9       Spotify Playlist Reach            72
# 8       Spotify Playlist Count            70
# 2                       Artist             5
# 28              Explicit Track             0
# 0                        Track             0
# 1                   Album Name             0
# 6                  Track Score             0
# 5                All Time Rank             0
# 4                         ISRC             0
# 3                 Release Date             0
# 29         Explicit Classified             0

# %% [markdown]
# I have decided to drop the columns in the dataset if the missing values is greater than 500 and drop only the rows with missing data if the dataset is less than 500.

# %%
for _, row in missing_values.iterrows():
    if row['missing_data'] > 500:
        df1.drop(columns=row['columns'], inplace=True)
    elif 0 < row['missing_data'] <= 500:
        df1.dropna(inplace=True, axis=0)


if df1.isnull().sum().sum() == 0:
    print("No missing values")
# Out:
# No missing values

# %% [markdown]
# and we are done with the missing data.
#
# let's confirm this.

# %%
missing_vals = df1.isnull().sum()
missing_vals
# Out:
# Track                     0
# Album Name                0
# Artist                    0
# Release Date              0
# ISRC                      0
# All Time Rank             0
# Track Score               0
# Spotify Streams           0
# Spotify Playlist Count    0
# Spotify Playlist Reach    0
# YouTube Views             0
# YouTube Likes             0
# AirPlay Spins             0
# Explicit Track            0
# Explicit Classified       0
# dtype: int64

# %% [markdown]
# Perfect. Let's deal with the datatypes.

# %% [markdown]
# ##Organising datatypes.

# %%
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3938 entries, 0 to 4599
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Track                   3938 non-null   object
#  1   Album Name              3938 non-null   object
#  2   Artist                  3938 non-null   object
#  3   Release Date            3938 non-null   object
#  4   ISRC                    3938 non-null   object
#  5   All Time Rank           3938 non-null   object
#  6   Track Score             3938 non-null   float64
#  7   Spotify Streams         3938 non-null   object
#  8   Spotify Playlist Count  3938 non-null   object
#  9   Spotify Playlist Reach  3938 non-null   object
#  10  YouTube Views           3938 non-null   object
#  11  YouTube Likes           3938 non-null   object
#  12  AirPlay Spins           3938 non-null   object
#  13  Explicit Track          3938 non-null   int64
#  14  Explicit Classified     3938 non-null   int64
# dtypes: float64(1), int64(2), object(12)
# memory usage: 492.2+ KB
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  YouTube Views YouTube Likes  \
# 0                 30,716            196,631,588     84,274,754     1,713,126
# 1                 28,113            174,597,137    116,347,040     3,486,739
# 2                 54,331            211,607,669    122,599,116     2,228,730
# 3                269,802            136,569,078  1,096,100,899    10,629,796
# 4                  7,223            151,469,874     77,373,957     3,670,188
#
#   AirPlay Spins  Explicit Track  Explicit Classified
# 0        40,975               0                    0
# 1        40,778               1                    1
# 2        74,333               0                    1
# 3     1,474,799               0                    0
# 4        12,185               1                    1

# %% [markdown]
# All columns besides 'Track', 'Album Name', 'Artist', 'Release Date' and 'ISRC' will be changed to integers
#
# 'Release Date' will be changed to datetime.

# %%
int_cols = ['All Time Rank', 'Track Score', 'Spotify Streams', 'Spotify Playlist Count', 'Spotify Playlist Reach', 'YouTube Views', 'YouTube Likes', 'AirPlay Spins']
df1[int_cols] = df1[int_cols].replace({',': ''}, regex=True).astype(int)
df1['Release Date'] = pd.to_datetime(df1['Release Date'])
df1['month'] = df1['Release Date'].dt.month
df1['year'] = df1['Release Date'].dt.year
df1.drop(columns='Explicit Track', inplace=True)
df1.rename(columns={'Explicit Classified': 'Explicit Track'}, inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3938 entries, 0 to 4599
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Track                   3938 non-null   object
#  1   Album Name              3938 non-null   object
#  2   Artist                  3938 non-null   object
#  3   Release Date            3938 non-null   datetime64[ns]
#  4   ISRC                    3938 non-null   object
#  5   All Time Rank           3938 non-null   int64
#  6   Track Score             3938 non-null   int64
#  7   Spotify Streams         3938 non-null   int64
#  8   Spotify Playlist Count  3938 non-null   int64
#  9   Spotify Playlist Reach  3938 non-null   int64
#  10  YouTube Views           3938 non-null   int64
#  11  YouTube Likes           3938 non-null   int64
#  12  AirPlay Spins           3938 non-null   int64
#  13  Explicit Track          3938 non-null   int64
#  14  month                   3938 non-null   int32
#  15  year                    3938 non-null   int32
# dtypes: datetime64[ns](1), int32(2), int64(9), object(4)
# memory usage: 621.3+ KB

# %%
df1.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC  All Time Rank  Track Score  Spotify Streams  \
# 0   2024-04-26  QM24S2402528              1          725        390470936
# 1   2024-05-04  USUG12400910              2          545        323703884
# 2   2024-03-19  QZJ842400387              3          538        601309283
# 3   2023-01-12  USSM12209777              4          444       2031280633
# 4   2024-05-31  USUG12403398              5          423        107034922
#
#    Spotify Playlist Count  Spotify Playlist Reach  YouTube Views  \
# 0                   30716               196631588       84274754
# 1                   28113               174597137      116347040
# 2                   54331               211607669      122599116
# 3                  269802               136569078     1096100899
# 4                    7223               151469874       77373957
#
#    YouTube Likes  AirPlay Spins  Explicit Track  month  year
# 0        1713126          40975               0      4  2024
# 1        3486739          40778               1      5  2024
# 2        2228730          74333               1      3  2024
# 3       10629796        1474799               0      1  2023
# 4        3670188          12185               1      5  2024

# %% [markdown]
# I want to make the headers more malleable by replacing the spaces between words with an underscore and removing all capital letters

# %%
df1.columns = df1.columns.str.replace(' ', '_').str.lower()
df1.head()
# Out:
#                         track                    album_name          artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   release_date          isrc  all_time_rank  track_score  spotify_streams  \
# 0   2024-04-26  QM24S2402528              1          725        390470936
# 1   2024-05-04  USUG12400910              2          545        323703884
# 2   2024-03-19  QZJ842400387              3          538        601309283
# 3   2023-01-12  USSM12209777              4          444       2031280633
# 4   2024-05-31  USUG12403398              5          423        107034922
#
#    spotify_playlist_count  spotify_playlist_reach  youtube_views  \
# 0                   30716               196631588       84274754
# 1                   28113               174597137      116347040
# 2                   54331               211607669      122599116
# 3                  269802               136569078     1096100899
# 4                    7223               151469874       77373957
#
#    youtube_likes  airplay_spins  explicit_track  month  year
# 0        1713126          40975               0      4  2024
# 1        3486739          40778               1      5  2024
# 2        2228730          74333               1      3  2024
# 3       10629796        1474799               0      1  2023
# 4        3670188          12185               1      5  2024

# %% [markdown]
# Yup, we are done with cleaning. let's save the dataframe for future use.

# %%
pat = "/content/drive/MyDrive/projects/datasets/spotify_cleaned.csv"
df1.to_csv(pat, index=False)

# %% [markdown]
# Hmm, this feels good.
#
# Let's repost an updated key features
# ##Key Features:
# + track: Name of the song.
# + album_name: Name of the album the song belongs to.
# + artist: Name of the artist(s) of the song.
# + release_date: Date when the song was released.
# + isrc: International Standard Recording Code for the song.
# + all_time_rank: Ranking of the song based on its all-time popularity.
# + track_score: Score assigned to the track based on various factors.
# + spotify_streams: Total number of streams on Spotify.
# + spotify_playlist_count: Number of Spotify playlists the song is included in.
# + spotify_playlist_reach: Reach of the song across Spotify playlists.
# + youtube_views: Total views of the song's official video on YouTube.
# + youtube_likes: Total likes on the song's official video on YouTube.
# + airplay_spins: Number of times the song has been played on radio stations.
# + explicit_track: Indicates whether the song contains explicit content.

# %% [markdown]
# The dataset doesn't have a column for genres so, we'll have to shelve our curiosity regarding song genres until a future date.
# We can still find the most poplar songs over the years. Which we are going to do

# %%
query1 = """
SELECT track, artist, MAX(spotify_streams) AS spotify_streams, MAX(youtube_views) AS youtube_views, MAX(airplay_spins) AS airplay_spins, year
FROM df1
GROUP BY year
ORDER BY year ASC,spotify_streams DESC, youtube_views DESC, airplay_spins DESC;
"""
result1 = psql.sqldf(query1)
result1
# Out:
#                                track                 artist  spotify_streams  \
# 0                Sweet Child O' Mine          Guns N' Roses       1879386440
# 1            Smells Like Teen Spirit                Nirvana       2021910364
# 2    All I Want for Christmas Is You           Mariah Carey       1810649765
# 3                    Beautiful Girls          Sean Kingston        178339925
# 4                    Californication  Red Hot Chili Peppers       1405353677
# 5                         In the End            Linkin Park       2045512421
# 6                   Over the Rainbow  Israel Kamakawiwo'ole        399145178
# 7                            Dilemma                  Nelly       2194935773
# 8                   Bring Me To Life            Evanescence       1720830668
# 9   Yeah! (feat. Lil Jon & Ludacris)                  USHER       2174022106
# 10                      Viva La Vida               Coldplay       2102223775
# 11                       Promiscuous          Nelly Furtado       1194124781
# 12                          Umbrella                Rihanna       1660504577
# 13                        Poker Face              Lady Gaga       1878098512
# 14                       Bad Romance              Lady Gaga       1587114096
# 15                        Sure Thing                 Miguel       2099862852
# 16    Rolling in the Deep - Acapella                  Adele       2502925593
# 17              Locked Out Of Heaven             Bruno Mars       2916412507
# 18                        Wake Me Up                 Avicii       2544489950
# 19                        Chandelier                    Sia       2379787239
# 20                      Stressed Out      Twenty One Pilots       2423583406
# 21                       Unstoppable                    Sia       3291262413
# 22           Cold Heart - PNAU Remix             Elton John       3909458734
# 23                        High Hopes    Panic! At The Disco       3427498835
# 24                   Blinding Lights             The Weeknd       4281468720
# 25                        Heat Waves          Glass Animals       2996181078
# 26         STAY (with Justin Bieber)          The Kid LAROI       3107100349
# 27                         As It Was           Harry Styles       3301814535
# 28                           Flowers            Miley Cyrus       2031280633
# 29                  Beautiful Things           Benson Boone        900158751
#
#     youtube_views  airplay_spins  year
# 0      2007460784         145671  1987
# 1       348081676         146813  1991
# 2       824500156         131873  1994
# 3      1499385808          17526  1998
# 4      1518596886          49257  1999
# 5      2375021286         186149  2000
# 6      1632844702          10999  2001
# 7      1864046384         173135  2002
# 8      2450982330         230782  2003
# 9      2970122390         261191  2004
# 10     1663636127         258525  2005
# 11     1251716030          74370  2006
# 12     1266946594         262819  2007
# 13     1600713698         287903  2008
# 14     2049116263         192196  2009
# 15     4062829308         471442  2010
# 16     5644117304         349469  2011
# 17     5849588091         378433  2012
# 18     4386626671         358498  2013
# 19     4151880976         244316  2014
# 20    16322756555         257332  2015
# 21     4086121880         654509  2016
# 22     9537135721         657334  2017
# 23     3435321800         671056  2018
# 24     3366447481        1695240  2019
# 25     2638957320        1414326  2020
# 26     1431591689        1510151  2021
# 27     6736502312        1777811  2022
# 28     2432265978        1474799  2023
# 29      389540239         383478  2024

# %% [markdown]
# If you look at the cell above, you'll notice that i decided to use the spotify streams as the primary decider to the rankings, this is not an error.
#
# Let's visualize.

# %% [markdown]
# ##Plotting popular songs over the years

# %%
from plotly.subplots import make_subplots
import plotly.graph_objs as go

fig = make_subplots(rows=1, cols=2, subplot_titles=('Most Popular Songs Over The Years', 'Most Popular Artists Over The Years'), horizontal_spacing=0.3)

fig.add_trace(go.Scatter(x=result1['year'], y=result1['track'], mode='lines+markers', name='Track'), row=1, col=1)
fig.add_trace(go.Scatter(x=result1['year'], y=result1['artist'], mode='markers', name='Artist'), row=1, col=2)

fig.update_xaxes(title_text='Year', row=1, col=1)
fig.update_yaxes(title_text='Track', row=1, col=1)
fig.update_xaxes(title_text='Year', row=1, col=2)
fig.update_yaxes(title_text='Artist', row=1, col=2)

fig.update_layout(width=1200, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e594f65-dfc6-4831-b889-4116db165f57" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e594f65-dfc6-4831-b889-4116db165f57")) {                    Plotly.newPlot(                        "9e594f65-dfc6-4831-b889-4116db165f57",                        [{"mode":"lines+markers","name":"Track","x":[1987,1991,1994,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"y":["Sweet Child O' Mine","Smells Like Teen Spirit","All I Want for Christmas Is You","Beautiful Girls","Californication","In the End","Over the Rainbow","Dilemma","Bring Me To Life","Yeah! (feat. Lil Jon & Ludacris)","Viva La Vida","Promiscuous","Umbrella","Poker Face","Bad Romance","Sure Thing","Rolling in the Deep - Acapella","Locked Out Of Heaven","Wake Me Up","Chandelier","Stressed Out","Unstoppable","Cold Heart - PNAU Remix","High Hopes","Blinding Lights","Heat Waves","STAY (with Justin Bieber)","As It Was","Flowers","Beautiful Things"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[1987,1991,1994,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"y":["Guns N' Roses","Nirvana","Mariah Carey","Sean Kingston","Red Hot Chili Peppers","Linkin Park","Israel Kamakawiwo'ole","Nelly","Evanescence","USHER","Coldplay","Nelly Furtado","Rihanna","Lady Gaga","Lady Gaga","Miguel","Adele","Bruno Mars","Avicii","Sia","Twenty One Pilots","Sia","Elton John","Panic! At The Disco","The Weeknd","Glass Animals","The Kid LAROI","Harry Styles","Miley Cyrus","Benson Boone"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...

# %% [markdown]
# Yay, it's interactive.

# %%
query2 = """
SELECT track, artist, spotify_streams, youtube_views, airplay_spins, month, year
FROM df1
WHERE year > 2009
ORDER BY year, month, spotify_streams DESC, youtube_views DESC, airplay_spins DESC;
"""
result2 = psql.sqldf(query2)
result2.head(20)
# Out:
#                                                 track             artist  \
# 0                                     Pumped Up Kicks  Foster The People
# 1                                        Danza Kuduro           Don Omar
# 2                                Love The Way You Lie             Eminem
# 3   Moves Like Jagger - Studio Recording From The ...           Maroon 5
# 4                                             Grenade         Bruno Mars
# 5                        Last Friday Night (T.G.I.F.)         Katy Perry
# 6                            Only Girl (In The World)            Rihanna
# 7                                            Dynamite          Taio Cruz
# 8                                            Firework         Katy Perry
# 9                                                Baby      Justin Bieber
# 10                              The One That Got Away         Katy Perry
# 11                                         Super Bass        Nicki Minaj
# 12                          DJ Got Us Fallin' In Love              USHER
# 13  Waka Waka (This Time for Africa) [The Official...            Shakira
# 14                                               Sail         AWOLNATION
# 15                                    What's My Name?            Rihanna
# 16                                              Taboo           Don Omar
# 17                                         Sure Thing             Miguel
# 18                                         Not Afraid             Eminem
# 19                                          Sex Music               Tank
#
#     spotify_streams  youtube_views  airplay_spins  month  year
# 0        1791778314      599930123         121067      1  2010
# 1        1656974409      597309937           9175      1  2010
# 2        1532052160     3009144927           4437      1  2010
# 3        1461578587      808548795           1132      1  2010
# 4        1313545266     1310515665         226445      1  2010
# 5        1144535829     1604084148         120606      1  2010
# 6        1085436198      162454294         227403      1  2010
# 7        1070923216      576914505         163744      1  2010
# 8        1065375074     1634743568         238231      1  2010
# 9         952635214     3312260344          15322      1  2010
# 10        921351898     1126799119          25625      1  2010
# 11        855080751     1308913092          65245      1  2010
# 12        841183589      485860020           2137      1  2010
# 13        829352129     4062829308          22773      1  2010
# 14        814264073      878157246          82779      1  2010
# 15        520418822     1049777851         100498      1  2010
# 16        210904340     1096124254           5612      1  2010
# 17       1335928309      165856240         471442      5  2010
# 18       1012914789     2040135706          10652      5  2010
# 19          5283089        7187358             99      6  2010

# %% [markdown]
# Shit, there's a problem, I wanted to track the rate of growth of each song track as some sort of KPI so that i could try to predict if a song will be popular and possibly build a model, but the release date of each song track is the only date stored as a record in the dataset and hence i cant use it for that purpose.
#
# Even the number of views on each platform isn't dated well enough for use as a time series.
#
# All hope isn't lost though, we can atleast make some pretty good interactive visualizations to work with during the dashboarding period.

# %% [markdown]
# We'll make visualizations for each of the years starting from 2010 to 2024 on the most popular song tracks and artists for each year the put that in a visualiztion and call it a day. We'll only use the views in regards to spotify to be the determining factor this time.

# %%
df1.columns
df1.head(1)
# Out:
#                  track                    album_name         artist  \
# 0  MILLION DOLLAR BABY  Million Dollar Baby - Single  Tommy Richman
#
#   release_date          isrc  all_time_rank  track_score  spotify_streams  \
# 0   2024-04-26  QM24S2402528              1          725        390470936
#
#    spotify_playlist_count  spotify_playlist_reach  youtube_views  \
# 0                   30716               196631588       84274754
#
#    youtube_likes  airplay_spins  explicit_track  month  year
# 0        1713126          40975               0      4  2024

# %%
query2010 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2010
ORDER BY spotify_streams DESC
LIMIT 20
"""
result2010 = psql.sqldf(query2010)
result2010
# Out:
#                                                 track             artist  \
# 0                                Just the Way You Are         Bruno Mars
# 1                                     Pumped Up Kicks  Foster The People
# 2                                        Danza Kuduro           Don Omar
# 3                                Love The Way You Lie             Eminem
# 4   Moves Like Jagger - Studio Recording From The ...           Maroon 5
# 5                                          Sure Thing             Miguel
# 6                                             Grenade         Bruno Mars
# 7                        Last Friday Night (T.G.I.F.)         Katy Perry
# 8                            Only Girl (In The World)            Rihanna
# 9                                            Dynamite          Taio Cruz
# 10                                           Firework         Katy Perry
# 11                                         Not Afraid             Eminem
# 12                                               Baby      Justin Bieber
# 13                                      The Lazy Song         Bruno Mars
# 14                              The One That Got Away         Katy Perry
# 15                                         Super Bass        Nicki Minaj
# 16                          DJ Got Us Fallin' In Love              USHER
# 17  Waka Waka (This Time for Africa) [The Official...            Shakira
# 18                                            Whistle           Flo Rida
# 19                                               Sail         AWOLNATION
#
#     spotify_streams
# 0        2099862852
# 1        1791778314
# 2        1656974409
# 3        1532052160
# 4        1461578587
# 5        1335928309
# 6        1313545266
# 7        1144535829
# 8        1085436198
# 9        1070923216
# 10       1065375074
# 11       1012914789
# 12        952635214
# 13        950810060
# 14        921351898
# 15        855080751
# 16        841183589
# 17        829352129
# 18        814272136
# 19        814264073

# %% [markdown]
# ###Plotting 2010 graph

# %%
fig1 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2010', 'The most popular Artists in 2010'), horizontal_spacing=0.3)

fig1.add_trace(go.Scatter(x = result2010['spotify_streams'], y = result2010['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig1.add_trace(go.Scatter(x = result2010['spotify_streams'], y = result2010['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig1.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig1.update_yaxes(title_text='Track', row=1, col=1)
fig1.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig1.update_yaxes(title_text='Artist', row=1, col=2)

fig1.update_layout(width=1500, height=600)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="67a5d938-01be-4922-878a-84d6a0d3a323" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67a5d938-01be-4922-878a-84d6a0d3a323")) {                    Plotly.newPlot(                        "67a5d938-01be-4922-878a-84d6a0d3a323",                        [{"mode":"markers","name":"Track","x":[2099862852,1791778314,1656974409,1532052160,1461578587,1335928309,1313545266,1144535829,1085436198,1070923216,1065375074,1012914789,952635214,950810060,921351898,855080751,841183589,829352129,814272136,814264073],"y":["Just the Way You Are","Pumped Up Kicks","Danza Kuduro","Love The Way You Lie","Moves Like Jagger - Studio Recording From The Voice Performance","Sure Thing","Grenade","Last Friday Night (T.G.I.F.)","Only Girl (In The World)","Dynamite","Firework","Not Afraid","Baby","The Lazy Song","The One That Got Away","Super Bass","DJ Got Us Fallin' In Love","Waka Waka (This Time for Africa) [The Official 2010 FIFA World Cup (TM) Song] (feat. Freshlyground)","Whistle","Sail"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2099862852,1791778314,1656974409,1532052160,1461578587,1335928309,1313545266,1144535829,1085436198,1070923216,1065375074,1012914789,952635214,950810060,921351898,855080751,841183589,829352129,814272136,814264073],"y":["Bruno Mars","Foster The People","Don Omar","Eminem","Maroon 5","Miguel","Bruno Mars","Katy Perry","Rihanna","Taio Cruz","Katy Perry","Eminem","Justin Bieber","Bruno Mars","Katy Perry","Nicki Minaj","USHER","Shakira","Flo Rida","AWOLNATION"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outli ...

# %% [markdown]
# Ignore the songs, focus more on the artists, pme of them were popular on multiple times

# %%
query2011 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2011
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2011 = psql.sqldf(query2011)
result2011
# Out:
#                                     track            artist  spotify_streams
# 0                       Thinking out Loud        Ed Sheeran       2502925593
# 1                            Stay With Me         Sam Smith       2086460781
# 2          Lean On (feat. Mï¿½ï¿½ & DJ Sn       Major Lazer       2080878370
# 3                             Uptown Funk       Mark Ronson       1993030264
# 4                        Someone Like You             Adele       1925879064
# 5                              The Nights            Avicii       1780761618
# 6            Somebody That I Used To Know             Gotye       1752826514
# 7                       Shut Up and Dance     WALK THE MOON       1690450389
# 8                           We Found Love           Rihanna       1655539775
# 9                        A Thousand Years   Christina Perri       1654956613
# 10                   Titanium (feat. Sia)               Sia       1634403761
# 11                      What Do You Mean?     Justin Bieber       1599742798
# 12                   Set Fire to the Rain             Adele       1595514674
# 13                     Summertime Sadness      Lana Del Rey       1442872605
# 14                        Ni**as In Paris             JAY-Z       1436087930
# 15  Young, Wild & Free (feat. Bruno Mars)        Snoop Dogg       1431126152
# 16  Young, Wild & Free (feat. Bruno Mars)        Snoop Dogg       1431126152
# 17                                Animals          Maroon 5       1365755853
# 18      Stereo Hearts (feat. Adam Levine)  Gym Class Heroes       1318596835
# 19                               Paradise          Coldplay       1291954163

# %% [markdown]
# ##Plotting 2011 graph

# %%
fig2 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2011', 'The most popular Artists in 2011'), horizontal_spacing=0.3)

fig2.add_trace(go.Scatter(x = result2011['spotify_streams'], y = result2011['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig2.add_trace(go.Scatter(x = result2011['spotify_streams'], y = result2011['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig2.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig2.update_yaxes(title_text='Track', row=1, col=1)
fig2.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig2.update_yaxes(title_text='Artist', row=1, col=2)

fig2.update_layout(width=1500, height=600)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7aa1fa80-0625-40f4-813d-dd0edfe0ef17" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aa1fa80-0625-40f4-813d-dd0edfe0ef17")) {                    Plotly.newPlot(                        "7aa1fa80-0625-40f4-813d-dd0edfe0ef17",                        [{"mode":"markers","name":"Track","x":[2502925593,2086460781,2080878370,1993030264,1925879064,1780761618,1752826514,1690450389,1655539775,1654956613,1634403761,1599742798,1595514674,1442872605,1436087930,1431126152,1431126152,1365755853,1318596835,1291954163],"y":["Thinking out Loud","Stay With Me","Lean On (feat. M\u00ef\u00bf\u00bd\u00ef\u00bf\u00bd & DJ Sn","Uptown Funk","Someone Like You","The Nights","Somebody That I Used To Know","Shut Up and Dance","We Found Love","A Thousand Years","Titanium (feat. Sia)","What Do You Mean?","Set Fire to the Rain","Summertime Sadness","Ni**as In Paris","Young, Wild & Free (feat. Bruno Mars)","Young, Wild & Free (feat. Bruno Mars)","Animals","Stereo Hearts (feat. Adam Levine)","Paradise"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2502925593,2086460781,2080878370,1993030264,1925879064,1780761618,1752826514,1690450389,1655539775,1654956613,1634403761,1599742798,1595514674,1442872605,1436087930,1431126152,1431126152,1365755853,1318596835,1291954163],"y":["Ed Sheeran","Sam Smith","Major Lazer","Mark Ronson","Adele","Avicii","Gotye","WALK THE MOON","Rihanna","Christina Perri","Sia","Justin Bieber","Adele","Lana Del Rey","JAY-Z","Snoop Dogg","Snoop Dogg","Maroon 5","Gym Class Heroes","Coldplay"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surfac ...

# %%
query2012 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2012
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2012 = psql.sqldf(query2012)
result2012
# Out:
#                              track             artist  spotify_streams
# 0                  Sweater Weather  The Neighbourhood       2916412507
# 1                     Another Love          Tom Odell       2444335468
# 2                        All of Me        John Legend       2382407025
# 3                           Demons    Imagine Dragons       2270796677
# 4                       Let Her Go          Passenger       2252713547
# 5                       Let Her Go          Passenger       2252713547
# 6              When I Was Your Man         Bruno Mars       2106040891
# 7             Locked Out Of Heaven         Bruno Mars       2004657631
# 8                      Radioactive    Imagine Dragons       1836362703
# 9                         Payphone           Maroon 5       1828026153
# 10               Cake By The Ocean               DNCE       1623436416
# 11                     Money Trees     Kendrick Lamar       1476217041
# 12  Hall of Fame (feat. will.i.am)         The Script       1438795892
# 13                        Diamonds            Rihanna       1419912461
# 14                   Call Me Maybe   Carly Rae Jepsen       1394048309
# 15                         Classic               MKTO       1350428257
# 16                            Stay            Rihanna       1313274600
# 17           Just Give Me a Reason               P!nk       1301573727
# 18                  Safe And Sound     Capital Cities       1286089822
# 19                          Ho Hey      The Lumineers       1273869800

# %% [markdown]
# ##Plotting 2012 graph

# %%
fig3 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2012', 'The most popular Artists in 2012'), horizontal_spacing=0.3)

fig3.add_trace(go.Scatter(x = result2012['spotify_streams'], y = result2012['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig3.add_trace(go.Scatter(x = result2012['spotify_streams'], y = result2012['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig3.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig3.update_yaxes(title_text='Track', row=1, col=1)
fig3.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig3.update_yaxes(title_text='Artist', row=1, col=2)

fig3.update_layout(width=1500, height=600)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="71fa61a1-d827-479e-8a5a-8dd776eab7c9" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71fa61a1-d827-479e-8a5a-8dd776eab7c9")) {                    Plotly.newPlot(                        "71fa61a1-d827-479e-8a5a-8dd776eab7c9",                        [{"mode":"markers","name":"Track","x":[2916412507,2444335468,2382407025,2270796677,2252713547,2252713547,2106040891,2004657631,1836362703,1828026153,1623436416,1476217041,1438795892,1419912461,1394048309,1350428257,1313274600,1301573727,1286089822,1273869800],"y":["Sweater Weather","Another Love","All of Me","Demons","Let Her Go","Let Her Go","When I Was Your Man","Locked Out Of Heaven","Radioactive","Payphone","Cake By The Ocean","Money Trees","Hall of Fame (feat. will.i.am)","Diamonds","Call Me Maybe","Classic","Stay","Just Give Me a Reason","Safe And Sound","Ho Hey"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2916412507,2444335468,2382407025,2270796677,2252713547,2252713547,2106040891,2004657631,1836362703,1828026153,1623436416,1476217041,1438795892,1419912461,1394048309,1350428257,1313274600,1301573727,1286089822,1273869800],"y":["The Neighbourhood","Tom Odell","John Legend","Imagine Dragons","Passenger","Passenger","Bruno Mars","Bruno Mars","Imagine Dragons","Maroon 5","DNCE","Kendrick Lamar","The Script","Rihanna","Carly Rae Jepsen","MKTO","Rihanna","P!nk","Capital Cities","The Lumineers"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[ ...

# %%
query2013 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2013
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2013 = psql.sqldf(query2013)
result2013
# Out:
#                                        track             artist  \
# 0                          Take Me to Church             Hozier
# 1                          Take Me to Church             Hozier
# 2                                    Riptide          Vance Joy
# 3                                 Photograph         Ed Sheeran
# 4                             Counting Stars        OneRepublic
# 5                                 Wake Me Up             Avicii
# 6                           Do I Wanna Know?     Arctic Monkeys
# 7                           Do I Wanna Know?     Arctic Monkeys
# 8                           I Wanna Be Yours     Arctic Monkeys
# 9   Why'd You Only Call Me When You're High?     Arctic Monkeys
# 10                                   Pompeii           Bastille
# 11                              Stolen Dance       Milky Chance
# 12                                Dark Horse         Katy Perry
# 13            Happy - From "Despicable Me 2"  Pharrell Williams
# 14             Rather Be (feat. Jess Glynne)       Clean Bandit
# 15                          Story of My Life      One Direction
# 16                       Young And Beautiful       Lana Del Rey
# 17                                      Roar         Katy Perry
# 18                                  Budapest        George Ezra
# 19                             White Iverson        Post Malone
#
#     spotify_streams
# 0        2544489950
# 1        2544489950
# 2        2541833602
# 3        2525355904
# 4        2466006842
# 5        2325017580
# 6        2188592950
# 7        2188592950
# 8        2185240293
# 9        1687828519
# 10       1590278292
# 11       1460945792
# 12       1445950326
# 13       1379786786
# 14       1327093253
# 15       1275036167
# 16       1256488099
# 17       1156191242
# 18       1142061871
# 19       1135209969

# %% [markdown]
# ##Plotting 2013 graph

# %%
fig4 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2013', 'The most popular Artists in 2013'), horizontal_spacing=0.3)

fig4.add_trace(go.Scatter(x = result2013['spotify_streams'], y = result2013['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig4.add_trace(go.Scatter(x = result2013['spotify_streams'], y = result2013['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig4.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig4.update_yaxes(title_text='Track', row=1, col=1)
fig4.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig4.update_yaxes(title_text='Artist', row=1, col=2)

fig4.update_layout(width=1500, height=600)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ba2bef0-444f-4643-aac3-3299e5f4ea49" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ba2bef0-444f-4643-aac3-3299e5f4ea49")) {                    Plotly.newPlot(                        "2ba2bef0-444f-4643-aac3-3299e5f4ea49",                        [{"mode":"markers","name":"Track","x":[2544489950,2544489950,2541833602,2525355904,2466006842,2325017580,2188592950,2188592950,2185240293,1687828519,1590278292,1460945792,1445950326,1379786786,1327093253,1275036167,1256488099,1156191242,1142061871,1135209969],"y":["Take Me to Church","Take Me to Church","Riptide","Photograph","Counting Stars","Wake Me Up","Do I Wanna Know?","Do I Wanna Know?","I Wanna Be Yours","Why'd You Only Call Me When You're High?","Pompeii","Stolen Dance","Dark Horse","Happy - From \"Despicable Me 2\"","Rather Be (feat. Jess Glynne)","Story of My Life","Young And Beautiful","Roar","Budapest","White Iverson"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2544489950,2544489950,2541833602,2525355904,2466006842,2325017580,2188592950,2188592950,2185240293,1687828519,1590278292,1460945792,1445950326,1379786786,1327093253,1275036167,1256488099,1156191242,1142061871,1135209969],"y":["Hozier","Hozier","Vance Joy","Ed Sheeran","OneRepublic","Avicii","Arctic Monkeys","Arctic Monkeys","Arctic Monkeys","Arctic Monkeys","Bastille","Milky Chance","Katy Perry","Pharrell Williams","Clean Bandit","One Direction","Lana Del Rey","Katy Perry","George Ezra","Post Malone"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0. ...

# %%
query2014 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2014
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2014 = psql.sqldf(query2014)
result2014
# Out:
#                                          track         artist  spotify_streams
# 0                       All of Me - Radio Edit    John Legend       2379787239
# 1                               No Role Modelz        J. Cole       2235160830
# 2                         I'm Not The Only One      Sam Smith       1879966374
# 3                                        Sugar       Maroon 5       1838092894
# 4                                  Blank Space   Taylor Swift       1829733410
# 5                                   Chandelier            Sia       1729264620
# 6                                         Maps       Maroon 5       1676528402
# 7   Cheerleader - Felix Jaehn Remix Radio Edit            OMI       1663491433
# 8                                Night Changes  One Direction       1548151634
# 9                                       Summer  Calvin Harris       1497564072
# 10                         A Sky Full of Stars       Coldplay       1490987063
# 11                               One Last Time  Ariana Grande       1465918510
# 12                               I Love You So    The Walters       1410353130
# 13                                Shake It Off   Taylor Swift       1409692678
# 14                                   Bang Bang       Jessie J       1336196012
# 15                           Time of Our Lives        Pitbull       1283683926
# 16                                  Wet Dreamz        J. Cole       1244864869
# 17                                       Style   Taylor Swift       1216966135
# 18                                   Let It Go      James Bay       1197774081
# 19                                   Centuries   Fall Out Boy       1184571362

# %% [markdown]
# ##Plotting 2014 Graph

# %%
fig5 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2014', 'The most popular Artists in 2014'), horizontal_spacing=0.3)

fig5.add_trace(go.Scatter(x = result2014['spotify_streams'], y = result2014['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig5.add_trace(go.Scatter(x = result2014['spotify_streams'], y = result2014['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig5.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig5.update_yaxes(title_text='Track', row=1, col=1)
fig5.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig5.update_yaxes(title_text='Artist', row=1, col=2)

fig5.update_layout(width=1500, height=600)
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8feb593e-d366-44c0-b89a-1cb200006434" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8feb593e-d366-44c0-b89a-1cb200006434")) {                    Plotly.newPlot(                        "8feb593e-d366-44c0-b89a-1cb200006434",                        [{"mode":"markers","name":"Track","x":[2379787239,2235160830,1879966374,1838092894,1829733410,1729264620,1676528402,1663491433,1548151634,1497564072,1490987063,1465918510,1410353130,1409692678,1336196012,1283683926,1244864869,1216966135,1197774081,1184571362],"y":["All of Me - Radio Edit","No Role Modelz","I'm Not The Only One","Sugar","Blank Space","Chandelier","Maps","Cheerleader - Felix Jaehn Remix Radio Edit","Night Changes","Summer","A Sky Full of Stars","One Last Time","I Love You So","Shake It Off","Bang Bang","Time of Our Lives","Wet Dreamz","Style","Let It Go","Centuries"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2379787239,2235160830,1879966374,1838092894,1829733410,1729264620,1676528402,1663491433,1548151634,1497564072,1490987063,1465918510,1410353130,1409692678,1336196012,1283683926,1244864869,1216966135,1197774081,1184571362],"y":["John Legend","J. Cole","Sam Smith","Maroon 5","Taylor Swift","Sia","Maroon 5","OMI","One Direction","Calvin Harris","Coldplay","Ariana Grande","The Walters","Taylor Swift","Jessie J","Pitbull","J. Cole","Taylor Swift","James Bay","Fall Out Boy"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333 ...

# %%
query2015 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2015
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2015 = psql.sqldf(query2015)
result2015
# Out:
#                                                 track             artist  \
# 0                                       Love Yourself      Justin Bieber
# 1                                        Stressed Out  Twenty One Pilots
# 2                                           The Hills         The Weeknd
# 3                            One Kiss (with Dua Lipa)      Calvin Harris
# 4                                           New Rules           Dua Lipa
# 5                                    The Night We Met         Lord Huron
# 6                                               Sorry      Justin Bieber
# 7                 I Took A Pill In Ibiza - Seeb Remix        Mike Posner
# 8                                               Faded        Alan Walker
# 9                                             7 Years       Lukas Graham
# 10                                           Stitches       Shawn Mendes
# 11                 See You Again (feat. Charlie Puth)        Wiz Khalifa
# 12         We Don't Talk Anymore (feat. Selena Gomez)       Charlie Puth
# 13                                      Cheap Thrills                Sia
# 14                                 Can't Feel My Face         The Weeknd
# 15                                               Ride  Twenty One Pilots
# 16                         The Less I Know The Better        Tame Impala
# 17                                              Hello              Adele
# 18  Love Me Like You Do - From "Fifty Shades Of Grey"     Ellie Goulding
# 19  Love Me Like You Do - From "Fifty Shades Of Grey"     Ellie Goulding
#
#     spotify_streams
# 0        2423583406
# 1        2313532702
# 2        2306740926
# 3        2178606166
# 4        2098443322
# 5        2097181065
# 6        2089476497
# 7        1949596473
# 8        1943842010
# 9        1916203330
# 10       1907768690
# 11       1891920348
# 12       1859886400
# 13       1779046979
# 14       1747534539
# 15       1724766252
# 16       1644031037
# 17       1550553401
# 18       1532983094
# 19       1532640437

# %% [markdown]
# ##Plotting 2015 graph
#
# If you noticed there seems to be a pattern in the graphs, it's a false notion that occurs due to ordering the data and the data structure itself.

# %%
fig6 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2015', 'The most popular Artists in 2015'), horizontal_spacing=0.3)

fig6.add_trace(go.Scatter(x = result2015['spotify_streams'], y = result2015['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig6.add_trace(go.Scatter(x = result2015['spotify_streams'], y = result2015['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig6.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig6.update_yaxes(title_text='Track', row=1, col=1)
fig6.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig6.update_yaxes(title_text='Artist', row=1, col=2)

fig6.update_layout(width=1500, height=600)
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a58fee4c-a283-436d-a809-dc698b9d86f7" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a58fee4c-a283-436d-a809-dc698b9d86f7")) {                    Plotly.newPlot(                        "a58fee4c-a283-436d-a809-dc698b9d86f7",                        [{"mode":"markers","name":"Track","x":[2423583406,2313532702,2306740926,2178606166,2098443322,2097181065,2089476497,1949596473,1943842010,1916203330,1907768690,1891920348,1859886400,1779046979,1747534539,1724766252,1644031037,1550553401,1532983094,1532640437],"y":["Love Yourself","Stressed Out","The Hills","One Kiss (with Dua Lipa)","New Rules","The Night We Met","Sorry","I Took A Pill In Ibiza - Seeb Remix","Faded","7 Years","Stitches","See You Again (feat. Charlie Puth)","We Don't Talk Anymore (feat. Selena Gomez)","Cheap Thrills","Can't Feel My Face","Ride","The Less I Know The Better","Hello","Love Me Like You Do - From \"Fifty Shades Of Grey\"","Love Me Like You Do - From \"Fifty Shades Of Grey\""],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2423583406,2313532702,2306740926,2178606166,2098443322,2097181065,2089476497,1949596473,1943842010,1916203330,1907768690,1891920348,1859886400,1779046979,1747534539,1724766252,1644031037,1550553401,1532983094,1532640437],"y":["Justin Bieber","Twenty One Pilots","The Weeknd","Calvin Harris","Dua Lipa","Lord Huron","Justin Bieber","Mike Posner","Alan Walker","Lukas Graham","Shawn Mendes","Wiz Khalifa","Charlie Puth","Sia","The Weeknd","Twenty One Pilots","Tame Impala","Adele","Ellie Goulding","Ellie Goulding"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surfa ...

# %%
query2016 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2016
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2016 = psql.sqldf(query2016)
result2016
# Out:
#                                                 track             artist  \
# 0                                             Starboy         The Weeknd
# 1                                           One Dance              Drake
# 2                                              Closer   The Chainsmokers
# 3                                Say You Won't Let Go       James Arthur
# 4                                          goosebumps       Travis Scott
# 5                                         Die For You         The Weeknd
# 6                                    Treat You Better       Shawn Mendes
# 7                                     Let Me Love You           DJ Snake
# 8                                  That's What I Like         Bruno Mars
# 9                     There's Nothing Holdin' Me Back       Shawn Mendes
# 10                                    Congratulations        Post Malone
# 11                                  Don't Let Me Down   The Chainsmokers
# 12                                         Me Rehï¿½ï        Danny Ocean
# 13                                           Heathens  Twenty One Pilots
# 14                                   I Feel It Coming         The Weeknd
# 15                          This Is What You Came For      Calvin Harris
# 16  CAN'T STOP THE FEELING! (Original Song From Dr...  Justin Timberlake
# 17  I Donï¿½ï¿½ï¿½t Wanna Live Forever (Fifty Shad...               ZAYN
# 18                                       I Fall Apart        Post Malone
# 19                                            Redbone   Childish Gambino
#
#     spotify_streams
# 0        3291262413
# 1        3192204066
# 2        2880536961
# 3        2830962669
# 4        2396737761
# 5        2265551950
# 6        2164074552
# 7        2147028486
# 8        2075459887
# 9        2043626431
# 10       1984802459
# 11       1888829482
# 12       1779760815
# 13       1777196966
# 14       1749088490
# 15       1746790923
# 16       1733302434
# 17       1662288901
# 18       1638216382
# 19       1615152539

# %% [markdown]
# ##Plotting 2016 graph

# %%
fig7 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2016', 'The most popular Artists in 2016'), horizontal_spacing=0.3)

fig7.add_trace(go.Scatter(x = result2016['spotify_streams'], y = result2016['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig7.add_trace(go.Scatter(x = result2016['spotify_streams'], y = result2016['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig7.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig7.update_yaxes(title_text='Track', row=1, col=1)
fig7.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig7.update_yaxes(title_text='Artist', row=1, col=2)

fig7.update_layout(width=1500, height=600)
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="87000222-6f6a-4713-863a-a2e0b935b0d4" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87000222-6f6a-4713-863a-a2e0b935b0d4")) {                    Plotly.newPlot(                        "87000222-6f6a-4713-863a-a2e0b935b0d4",                        [{"mode":"markers","name":"Track","x":[3291262413,3192204066,2880536961,2830962669,2396737761,2265551950,2164074552,2147028486,2075459887,2043626431,1984802459,1888829482,1779760815,1777196966,1749088490,1746790923,1733302434,1662288901,1638216382,1615152539],"y":["Starboy","One Dance","Closer","Say You Won't Let Go","goosebumps","Die For You","Treat You Better","Let Me Love You","That's What I Like","There's Nothing Holdin' Me Back","Congratulations","Don't Let Me Down","Me Reh\u00ef\u00bf\u00bd\u00ef","Heathens","I Feel It Coming","This Is What You Came For","CAN'T STOP THE FEELING! (Original Song From Dreamworks Animation's \"Trolls\")","I Don\u00ef\u00bf\u00bd\u00ef\u00bf\u00bd\u00ef\u00bf\u00bdt Wanna Live Forever (Fifty Shades D","I Fall Apart","Redbone"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[3291262413,3192204066,2880536961,2830962669,2396737761,2265551950,2164074552,2147028486,2075459887,2043626431,1984802459,1888829482,1779760815,1777196966,1749088490,1746790923,1733302434,1662288901,1638216382,1615152539],"y":["The Weeknd","Drake","The Chainsmokers","James Arthur","Travis Scott","The Weeknd","Shawn Mendes","DJ Snake","Bruno Mars","Shawn Mendes","Post Malone","The Chainsmokers","Danny Ocean","Twenty One Pilots","The Weeknd","Calvin Harris","Justin Timberlake","ZAYN","Post Malone","Childish Gambino"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
query2017 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2017
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2017 = psql.sqldf(query2017)
result2017
# Out:
#                              track            artist  spotify_streams
# 0                     Shape of You        Ed Sheeran       3909458734
# 1                         Believer   Imagine Dragons       3006226762
# 2                          Perfect        Ed Sheeran       2969999682
# 3       rockstar (feat. 21 Savage)       Post Malone       2960046642
# 4         Something Just Like This  The Chainsmokers       2596644721
# 5                          Thunder   Imagine Dragons       2384768901
# 6                          HUMBLE.    Kendrick Lamar       2226869580
# 7                    XO Tour Llif3      Lil Uzi Vert       2123458039
# 8                    XO Tour Llif3      Lil Uzi Vert       2123458039
# 9        Havana (feat. Young Thug)    Camila Cabello       2072182782
# 10                   Unforgettable    French Montana       2065697126
# 11            Too Good At Goodbyes         Sam Smith       2061017397
# 12         Cold Heart - PNAU Remix        Elton John       2011121774
# 13                       Attention      Charlie Puth       1800254516
# 14                I Like Me Better              Lauv       1784308411
# 15                      Me Rehï¿½ï       Danny Ocean       1778934858
# 16                       Despacito        Luis Fonsi       1747093405
# 17               Despacito - Remix        Luis Fonsi       1713294983
# 18     Dusk Till Dawn - Radio Edit              ZAYN       1687683940
# 19  Girls Like You (feat. Cardi B)          Maroon 5       1650167380

# %% [markdown]
# ##Plotting 2017 graph

# %%
fig8 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2017', 'The most popular Artists in 2017'), horizontal_spacing=0.3)

fig8.add_trace(go.Scatter(x = result2017['spotify_streams'], y = result2017['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig8.add_trace(go.Scatter(x = result2017['spotify_streams'], y = result2017['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig8.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig8.update_yaxes(title_text='Track', row=1, col=1)
fig8.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig8.update_yaxes(title_text='Artist', row=1, col=2)

fig8.update_layout(width=1500, height=600)
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6e2c341e-b2ac-4d00-8d9d-060fb66ee5c4" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e2c341e-b2ac-4d00-8d9d-060fb66ee5c4")) {                    Plotly.newPlot(                        "6e2c341e-b2ac-4d00-8d9d-060fb66ee5c4",                        [{"mode":"markers","name":"Track","x":[3909458734,3006226762,2969999682,2960046642,2596644721,2384768901,2226869580,2123458039,2123458039,2072182782,2065697126,2061017397,2011121774,1800254516,1784308411,1778934858,1747093405,1713294983,1687683940,1650167380],"y":["Shape of You","Believer","Perfect","rockstar (feat. 21 Savage)","Something Just Like This","Thunder","HUMBLE.","XO Tour Llif3","XO Tour Llif3","Havana (feat. Young Thug)","Unforgettable","Too Good At Goodbyes","Cold Heart - PNAU Remix","Attention","I Like Me Better","Me Reh\u00ef\u00bf\u00bd\u00ef","Despacito","Despacito - Remix","Dusk Till Dawn - Radio Edit","Girls Like You (feat. Cardi B)"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[3909458734,3006226762,2969999682,2960046642,2596644721,2384768901,2226869580,2123458039,2123458039,2072182782,2065697126,2061017397,2011121774,1800254516,1784308411,1778934858,1747093405,1713294983,1687683940,1650167380],"y":["Ed Sheeran","Imagine Dragons","Ed Sheeran","Post Malone","The Chainsmokers","Imagine Dragons","Kendrick Lamar","Lil Uzi Vert","Lil Uzi Vert","Camila Cabello","French Montana","Sam Smith","Elton John","Charlie Puth","Lauv","Danny Ocean","Luis Fonsi","Luis Fonsi","ZAYN","Maroon 5"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"tick ...

# %%
query2018 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2018
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2018 = psql.sqldf(query2018)
result2018
# Out:
#                                             track               artist  \
# 0                               Someone You Loved        Lewis Capaldi
# 1   Sunflower - Spider-Man: Into the Spider-Verse          Post Malone
# 2                                       Seï¿½ï¿½o         Shawn Mendes
# 3                                    Lucid Dreams           Juice WRLD
# 4                                      God's Plan                Drake
# 5                                         Shallow            Lady Gaga
# 6                                            SAD!         XXXTENTACION
# 7                                         Happier           Marshmello
# 8                                      SICKO MODE         Travis Scott
# 9                                      Without Me               Halsey
# 10                                     Better Now          Post Malone
# 11                                      Moonlight         XXXTENTACION
# 12                                  thank u, next        Ariana Grande
# 13                          when the party's over        Billie Eilish
# 14                                     Youngblood  5 Seconds of Summer
# 15                               Call Out My Name           The Weeknd
# 16                                     Be Alright           Dean Lewis
# 17                Eastside (with Halsey & Khalid)         benny blanco
# 18                             Let Me Down Slowly        Alec Benjamin
# 19                                           Wow.          Post Malone
#
#     spotify_streams
# 0        3427498835
# 1        3358704125
# 2        2738293818
# 3        2548389305
# 4        2529948475
# 5        2447973078
# 6        2218531106
# 7        2143821605
# 8        2134271997
# 9        2042792456
# 10       1953403531
# 11       1885431727
# 12       1878196824
# 13       1845938685
# 14       1790579305
# 15       1780889877
# 16       1749353402
# 17       1736530084
# 18       1709991997
# 19       1680612367

# %% [markdown]
# ##Plotting 2018 graph

# %%
fig9 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2018', 'The most popular Artists in 2018'), horizontal_spacing=0.3)

fig9.add_trace(go.Scatter(x = result2018['spotify_streams'], y = result2018['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig9.add_trace(go.Scatter(x = result2018['spotify_streams'], y = result2018['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig9.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig9.update_yaxes(title_text='Track', row=1, col=1)
fig9.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig9.update_yaxes(title_text='Artist', row=1, col=2)

fig9.update_layout(width=1500, height=600)
fig9.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e294420c-4f03-405d-83ef-768ce9407859" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e294420c-4f03-405d-83ef-768ce9407859")) {                    Plotly.newPlot(                        "e294420c-4f03-405d-83ef-768ce9407859",                        [{"mode":"markers","name":"Track","x":[3427498835,3358704125,2738293818,2548389305,2529948475,2447973078,2218531106,2143821605,2134271997,2042792456,1953403531,1885431727,1878196824,1845938685,1790579305,1780889877,1749353402,1736530084,1709991997,1680612367],"y":["Someone You Loved","Sunflower - Spider-Man: Into the Spider-Verse","Se\u00ef\u00bf\u00bd\u00ef\u00bf\u00bdo","Lucid Dreams","God's Plan","Shallow","SAD!","Happier","SICKO MODE","Without Me","Better Now","Moonlight","thank u, next","when the party's over","Youngblood","Call Out My Name","Be Alright","Eastside (with Halsey & Khalid)","Let Me Down Slowly","Wow."],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[3427498835,3358704125,2738293818,2548389305,2529948475,2447973078,2218531106,2143821605,2134271997,2042792456,1953403531,1885431727,1878196824,1845938685,1790579305,1780889877,1749353402,1736530084,1709991997,1680612367],"y":["Lewis Capaldi","Post Malone","Shawn Mendes","Juice WRLD","Drake","Lady Gaga","XXXTENTACION","Marshmello","Travis Scott","Halsey","Post Malone","XXXTENTACION","Ariana Grande","Billie Eilish","5 Seconds of Summer","The Weeknd","Dean Lewis","benny blanco","Alec Benjamin","Post Malone"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d ...

# %%
query2019 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2019
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2019 = psql.sqldf(query2019)
result2019
# Out:
#                                 track          artist  spotify_streams
# 0                     Blinding Lights      The Weeknd       4281468720
# 1                        Dance Monkey     Tones And I       3071214106
# 2                    Watermelon Sugar    Harry Styles       2708151499
# 3                     Don't Start Now        Dua Lipa       2607121959
# 4                             bad guy   Billie Eilish       2516804300
# 5                             Circles     Post Malone       2481391466
# 6                             7 rings   Ariana Grande       2262490403
# 7                        Cruel Summer    Taylor Swift       2188247133
# 8                            Memories        Maroon 5       2011072164
# 9               Roses - Imanbek Remix       SAINt JHN       1927961994
# 10                      Before You Go   Lewis Capaldi       1920784716
# 11                            The Box     Roddy Ricch       1911559785
# 12  I Don't Care (with Justin Bieber)      Ed Sheeran       1816356140
# 13                        LA CANCIï¿½        J Balvin       1706325903
# 14                          Adore You    Harry Styles       1670164200
# 15   death bed (coffee for your head)           Powfu       1656385770
# 16                HIGHEST IN THE ROOM    Travis Scott       1625149693
# 17              Old Town Road - Remix       Lil Nas X       1527106099
# 18                               Tusa         KAROL G       1497511486
# 19                            ROXANNE  Arizona Zervas       1474968552

# %% [markdown]
# ##Plotting 2019 graph

# %%
fig10 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2019', 'The most popular Artists in 2019'), horizontal_spacing=0.3)

fig10.add_trace(go.Scatter(x = result2019['spotify_streams'], y = result2019['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig10.add_trace(go.Scatter(x = result2019['spotify_streams'], y = result2019['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig10.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig10.update_yaxes(title_text='Track', row=1, col=1)
fig10.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig10.update_yaxes(title_text='Artist', row=1, col=2)

fig10.update_layout(width=1500, height=600)
fig10.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0fe57d2f-7dae-4455-913a-83b56195795a" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0fe57d2f-7dae-4455-913a-83b56195795a")) {                    Plotly.newPlot(                        "0fe57d2f-7dae-4455-913a-83b56195795a",                        [{"mode":"markers","name":"Track","x":[4281468720,3071214106,2708151499,2607121959,2516804300,2481391466,2262490403,2188247133,2011072164,1927961994,1920784716,1911559785,1816356140,1706325903,1670164200,1656385770,1625149693,1527106099,1497511486,1474968552],"y":["Blinding Lights","Dance Monkey","Watermelon Sugar","Don't Start Now","bad guy","Circles","7 rings","Cruel Summer","Memories","Roses - Imanbek Remix","Before You Go","The Box","I Don't Care (with Justin Bieber)","LA CANCI\u00ef\u00bf\u00bd","Adore You","death bed (coffee for your head)","HIGHEST IN THE ROOM","Old Town Road - Remix","Tusa","ROXANNE"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[4281468720,3071214106,2708151499,2607121959,2516804300,2481391466,2262490403,2188247133,2011072164,1927961994,1920784716,1911559785,1816356140,1706325903,1670164200,1656385770,1625149693,1527106099,1497511486,1474968552],"y":["The Weeknd","Tones And I","Harry Styles","Dua Lipa","Billie Eilish","Post Malone","Ariana Grande","Taylor Swift","Maroon 5","SAINt JHN","Lewis Capaldi","Roddy Ricch","Ed Sheeran","J Balvin","Harry Styles","Powfu","Travis Scott","Lil Nas X","KAROL G","Arizona Zervas"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...

# %%
query2020 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2020
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2020 = psql.sqldf(query2020)
result2020
# Out:
#                                            track          artist  \
# 0                                     Heat Waves   Glass Animals
# 1                      Levitating (feat. DaBaby)        Dua Lipa
# 2                                Save Your Tears      The Weeknd
# 3                                         Dakiti       Bad Bunny
# 4                                       Dynamite             BTS
# 5                         Mood (feat. iann dior)        24kGoldn
# 6                                     Bad Habits      Ed Sheeran
# 7                                        Heather      Conan Gray
# 8                   ROCKSTAR (feat. Roddy Ricch)          DaBaby
# 9                                        Shivers      Ed Sheeran
# 10  Save Your Tears (with Ariana Grande) (Remix)      The Weeknd
# 11                   Godzilla (feat. Juice WRLD)          Eminem
# 12                            you broke me first      Tate McRae
# 13                                     positions   Ariana Grande
# 14               WAP (feat. Megan Thee Stallion)         Cardi B
# 15                                      Lemonade  Internet Money
# 16                                      cardigan    Taylor Swift
# 17                                        Hawï¿½          Maluma
# 18                    Life Is Good (feat. Drake)          Future
# 19                                Break My Heart        Dua Lipa
#
#     spotify_streams
# 0        2996181078
# 1        2074721986
# 2        1995511952
# 3        1977947460
# 4        1872577908
# 5        1867736006
# 6        1754311538
# 7        1675083208
# 8        1638836101
# 9        1568058093
# 10       1549317525
# 11       1456635235
# 12       1439465700
# 13       1432830108
# 14       1325725696
# 15       1320495311
# 16       1307283069
# 17       1289186767
# 18       1237874594
# 19       1198689895

# %% [markdown]
# ##Plotting 2020 graph

# %%
fig11 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2020', 'The most popular Artists in 2020'), horizontal_spacing=0.3)

fig11.add_trace(go.Scatter(x = result2020['spotify_streams'], y = result2020['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig11.add_trace(go.Scatter(x = result2020['spotify_streams'], y = result2020['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig11.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig11.update_yaxes(title_text='Track', row=1, col=1)
fig11.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig11.update_yaxes(title_text='Artist', row=1, col=2)

fig11.update_layout(width=1500, height=600)
fig11.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="544a3d04-d149-4301-a902-3502520dd6af" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("544a3d04-d149-4301-a902-3502520dd6af")) {                    Plotly.newPlot(                        "544a3d04-d149-4301-a902-3502520dd6af",                        [{"mode":"markers","name":"Track","x":[2996181078,2074721986,1995511952,1977947460,1872577908,1867736006,1754311538,1675083208,1638836101,1568058093,1549317525,1456635235,1439465700,1432830108,1325725696,1320495311,1307283069,1289186767,1237874594,1198689895],"y":["Heat Waves","Levitating (feat. DaBaby)","Save Your Tears","Dakiti","Dynamite","Mood (feat. iann dior)","Bad Habits","Heather","ROCKSTAR (feat. Roddy Ricch)","Shivers","Save Your Tears (with Ariana Grande) (Remix)","Godzilla (feat. Juice WRLD)","you broke me first","positions","WAP (feat. Megan Thee Stallion)","Lemonade","cardigan","Haw\u00ef\u00bf\u00bd","Life Is Good (feat. Drake)","Break My Heart"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2996181078,2074721986,1995511952,1977947460,1872577908,1867736006,1754311538,1675083208,1638836101,1568058093,1549317525,1456635235,1439465700,1432830108,1325725696,1320495311,1307283069,1289186767,1237874594,1198689895],"y":["Glass Animals","Dua Lipa","The Weeknd","Bad Bunny","BTS","24kGoldn","Ed Sheeran","Conan Gray","DaBaby","Ed Sheeran","The Weeknd","Eminem","Tate McRae","Ariana Grande","Cardi B","Internet Money","Taylor Swift","Maluma","Future","Dua Lipa"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887 ...

# %%
query2021 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2021
ORDER BY spotify_streams DESC
LIMIT 20
"""

result2021 = psql.sqldf(query2021)
result2021
# Out:
#                                      track          artist  spotify_streams
# 0                STAY (with Justin Bieber)   The Kid LAROI       3107100349
# 1                          drivers license  Olivia Rodrigo       2184754018
# 2                                 good 4 u  Olivia Rodrigo       2167768056
# 3        INDUSTRY BABY (feat. Jack Harlow)       Lil Nas X       2014959725
# 4        INDUSTRY BABY (feat. Jack Harlow)       Lil Nas X       2014959725
# 5           MONTERO (Call Me By Your Name)       Lil Nas X       1902241314
# 6           MONTERO (Call Me By Your Name)       Lil Nas X       1902241314
# 7                 Kiss Me More (feat. SZA)        Doja Cat       1823871908
# 8                 Kiss Me More (feat. SZA)        Doja Cat       1823871908
# 9                               Easy On Me           Adele       1720918065
# 10  Peaches (feat. Daniel Caesar & Giveon)   Justin Bieber       1612286123
# 11                                 deja vu  Olivia Rodrigo       1606975517
# 12                                   Woman        Doja Cat       1606950381
# 13                                   Ghost   Justin Bieber       1586830204
# 14                                 traitor  Olivia Rodrigo       1564979439
# 15                                   Pepas         Farruko       1500499584
# 16                                Yonaguni       Bad Bunny       1398634184
# 17                              Todo De Ti  Rauw Alejandro       1339352060
# 18                       Happier Than Ever   Billie Eilish       1321878145
# 19                     Leave The Door Open      Bruno Mars       1312168384

# %% [markdown]
# ##Plotting 2021 graph

# %%
fig12 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2021', 'The most popular Artists in 2021'), horizontal_spacing=0.3)

fig12.add_trace(go.Scatter(x = result2021['spotify_streams'], y = result2021['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig12.add_trace(go.Scatter(x = result2021['spotify_streams'], y = result2021['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig12.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig12.update_yaxes(title_text='Track', row=1, col=1)
fig12.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig12.update_yaxes(title_text='Artist', row=1, col=2)

fig12.update_layout(width=1500, height=600)
fig12.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94b21a37-f1ac-4819-bb04-0d0d7c0dee76" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94b21a37-f1ac-4819-bb04-0d0d7c0dee76")) {                    Plotly.newPlot(                        "94b21a37-f1ac-4819-bb04-0d0d7c0dee76",                        [{"mode":"markers","name":"Track","x":[3107100349,2184754018,2167768056,2014959725,2014959725,1902241314,1902241314,1823871908,1823871908,1720918065,1612286123,1606975517,1606950381,1586830204,1564979439,1500499584,1398634184,1339352060,1321878145,1312168384],"y":["STAY (with Justin Bieber)","drivers license","good 4 u","INDUSTRY BABY (feat. Jack Harlow)","INDUSTRY BABY (feat. Jack Harlow)","MONTERO (Call Me By Your Name)","MONTERO (Call Me By Your Name)","Kiss Me More (feat. SZA)","Kiss Me More (feat. SZA)","Easy On Me","Peaches (feat. Daniel Caesar & Giveon)","deja vu","Woman","Ghost","traitor","Pepas","Yonaguni","Todo De Ti","Happier Than Ever","Leave The Door Open"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[3107100349,2184754018,2167768056,2014959725,2014959725,1902241314,1902241314,1823871908,1823871908,1720918065,1612286123,1606975517,1606950381,1586830204,1564979439,1500499584,1398634184,1339352060,1321878145,1312168384],"y":["The Kid LAROI","Olivia Rodrigo","Olivia Rodrigo","Lil Nas X","Lil Nas X","Lil Nas X","Lil Nas X","Doja Cat","Doja Cat","Adele","Justin Bieber","Olivia Rodrigo","Doja Cat","Justin Bieber","Olivia Rodrigo","Farruko","Bad Bunny","Rauw Alejandro","Billie Eilish","Bruno Mars"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth ...

# %%
query2022 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2022
ORDER BY spotify_streams DESC
LIMIT 20
"""
result2022 = psql.sqldf(query2022)
result2022
# Out:
#                                      track           artist  spotify_streams
# 0                                As It Was     Harry Styles       3301814535
# 1                                Kill Bill              SZA       1873746537
# 2                          Me Porto Bonito        Bad Bunny       1811990630
# 3                               La Bachata    Manuel Turizo       1721045197
# 4    Quevedo: Bzrp Music Sessions, Vol. 52         Bizarrap       1692951462
# 5                          I'm Good (Blue)     David Guetta       1658229422
# 6                          I Ain't Worried      OneRepublic       1607421145
# 7                                Anti-Hero     Taylor Swift       1563224246
# 8                Unholy (feat. Kim Petras)        Sam Smith       1556275789
# 9                       Titï¿½ï¿½ Me Pregu        Bad Bunny       1514239759
# 10                           Ojitos Lindos        Bad Bunny       1421763497
# 11           Calm Down (with Selena Gomez)             Rema       1391688322
# 12  Creepin' (with The Weeknd & 21 Savage)     Metro Boomin       1337619917
# 13                                  Efecto        Bad Bunny       1293773697
# 14                           Glimpse of Us             Joji       1262308912
# 15                                   Bones  Imagine Dragons       1227475431
# 16                                PROVENZA          KAROL G       1185929926
# 17                       Romantic Homicide             d4vd       1136504636
# 18                             golden hour             JVKE       1126986320
# 19                             Moscow Mule        Bad Bunny       1108031580

# %% [markdown]
# ##Plotting 2022 graph

# %%
fig13 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2022', 'The most popular Artists in 2022'), horizontal_spacing=0.3)

fig13.add_trace(go.Scatter(x = result2022['spotify_streams'], y = result2022['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig13.add_trace(go.Scatter(x = result2022['spotify_streams'], y = result2022['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig13.update_xaxes(title_text='Spotify Views', row=1, col=1)
fig13.update_yaxes(title_text='Track', row=1, col=1)
fig13.update_xaxes(title_text='Spotify Views', row=1, col=2)
fig13.update_yaxes(title_text='Artist', row=1, col=2)

fig13.update_layout(width=1500, height=600)
fig13.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4777105c-668c-4d6a-a0b3-d2c4a63b2ed2" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4777105c-668c-4d6a-a0b3-d2c4a63b2ed2")) {                    Plotly.newPlot(                        "4777105c-668c-4d6a-a0b3-d2c4a63b2ed2",                        [{"mode":"markers","name":"Track","x":[3301814535,1873746537,1811990630,1721045197,1692951462,1658229422,1607421145,1563224246,1556275789,1514239759,1421763497,1391688322,1337619917,1293773697,1262308912,1227475431,1185929926,1136504636,1126986320,1108031580],"y":["As It Was","Kill Bill","Me Porto Bonito","La Bachata","Quevedo: Bzrp Music Sessions, Vol. 52","I'm Good (Blue)","I Ain't Worried","Anti-Hero","Unholy (feat. Kim Petras)","Tit\u00ef\u00bf\u00bd\u00ef\u00bf\u00bd Me Pregu","Ojitos Lindos","Calm Down (with Selena Gomez)","Creepin' (with The Weeknd & 21 Savage)","Efecto","Glimpse of Us","Bones","PROVENZA","Romantic Homicide","golden hour","Moscow Mule"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[3301814535,1873746537,1811990630,1721045197,1692951462,1658229422,1607421145,1563224246,1556275789,1514239759,1421763497,1391688322,1337619917,1293773697,1262308912,1227475431,1185929926,1136504636,1126986320,1108031580],"y":["Harry Styles","SZA","Bad Bunny","Manuel Turizo","Bizarrap","David Guetta","OneRepublic","Taylor Swift","Sam Smith","Bad Bunny","Bad Bunny","Rema","Metro Boomin","Bad Bunny","Joji","Imagine Dragons","KAROL G","d4vd","JVKE","Bad Bunny"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0 ...

# %%
query2023 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2023
ORDER BY spotify_streams DESC
LIMIT 20
"""
result2023 = psql.sqldf(query2023)
result2023
# Out:
#                                                 track          artist  \
# 0                                             Flowers     Miley Cyrus
# 1                 Seven (feat. Latto) (Explicit Ver.)       Jung Kook
# 2                                              greedy      Tate McRae
# 3                                     Ella Baila Sola  Eslabon Armado
# 4                                          Like Crazy           Jimin
# 5                                            Daylight   David Kushner
# 6                                  Paint The Town Red        Doja Cat
# 7                                     La Bebe - Remix       Yng Lvcas
# 8                                                 TQG         KAROL G
# 9                                           un x100to  Grupo Frontera
# 10                                            vampire  Olivia Rodrigo
# 11                              My Love Mine All Mine          Mitski
# 12              Shakira: Bzrp Music Sessions, Vol. 53        Bizarrap
# 13                                               LALA     Myke Towers
# 14                                         Last Night   Morgan Wallen
# 15  What Was I Made For? [From The Motion Picture ...   Billie Eilish
# 16                                         Classy 101            Feid
# 17                                  Cupid - Twin Ver.     FIFTY FIFTY
# 18            Dance The Night - From Barbie The Album        Dua Lipa
# 19                                    Dance The Night        Dua Lipa
#
#     spotify_streams
# 0        2031280633
# 1        1673557134
# 2        1258569694
# 3        1215336974
# 4        1165398518
# 5        1126820069
# 6        1065399331
# 7        1032225805
# 8        1024381758
# 9        1008495696
# 10        998964097
# 11        997702304
# 12        946941510
# 13        925655569
# 14        922010059
# 15        891720245
# 16        872148396
# 17        861388470
# 18        860026452
# 19        860026452

# %% [markdown]
# ##Plotting 2023 graph

# %%
fig14 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2023', 'The most popular Artists in 2023'), horizontal_spacing=0.3)

fig14.add_trace(go.Scatter(x = result2023['spotify_streams'], y = result2023['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig14.add_trace(go.Scatter(x = result2023['spotify_streams'], y = result2023['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig14.update_xaxes(title_text='Spotify Streams', row=1, col=1)
fig14.update_yaxes(title_text='Track', row=1, col=1)
fig14.update_xaxes(title_text='Spotify Streams', row=1, col=2)
fig14.update_yaxes(title_text='Artist', row=1, col=2)

fig14.update_layout(width=1500, height=600)
fig14.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="535b914e-8109-4ac5-85f8-e4e1c1db6354" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("535b914e-8109-4ac5-85f8-e4e1c1db6354")) {                    Plotly.newPlot(                        "535b914e-8109-4ac5-85f8-e4e1c1db6354",                        [{"mode":"markers","name":"Track","x":[2031280633,1673557134,1258569694,1215336974,1165398518,1126820069,1065399331,1032225805,1024381758,1008495696,998964097,997702304,946941510,925655569,922010059,891720245,872148396,861388470,860026452,860026452],"y":["Flowers","Seven (feat. Latto) (Explicit Ver.)","greedy","Ella Baila Sola","Like Crazy","Daylight","Paint The Town Red","La Bebe - Remix","TQG","un x100to","vampire","My Love Mine All Mine","Shakira: Bzrp Music Sessions, Vol. 53","LALA","Last Night","What Was I Made For? [From The Motion Picture \"Barbie\"]","Classy 101","Cupid - Twin Ver.","Dance The Night - From Barbie The Album","Dance The Night"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[2031280633,1673557134,1258569694,1215336974,1165398518,1126820069,1065399331,1032225805,1024381758,1008495696,998964097,997702304,946941510,925655569,922010059,891720245,872148396,861388470,860026452,860026452],"y":["Miley Cyrus","Jung Kook","Tate McRae","Eslabon Armado","Jimin","David Kushner","Doja Cat","Yng Lvcas","KAROL G","Grupo Frontera","Olivia Rodrigo","Mitski","Bizarrap","Myke Towers","Morgan Wallen","Billie Eilish","Feid","FIFTY FIFTY","Dua Lipa","Dua Lipa"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...

# %%
query2024 = """
SELECT track, artist, spotify_streams
FROM df1
WHERE year = 2024
ORDER BY spotify_streams DESC
LIMIT 20
"""
result2024 = psql.sqldf(query2024)
result2024
# Out:
#                                        track             artist  \
# 0                           Beautiful Things       Benson Boone
# 1                                  Gata Only         FloyyMenor
# 2                 i like the way you kiss me            Artemas
# 3   we can't be friends (wait for your love)      Ariana Grande
# 4                                   Espresso  Sabrina Carpenter
# 5                                  Too Sweet             Hozier
# 6                                  Too Sweet             Hozier
# 7                                   CARNIVAL                ýý$
# 8                                     redrum          21 Savage
# 9                             TEXAS HOLD 'EM           Beyoncï¿
# 10                                 yes, and?      Ariana Grande
# 11             Fortnight (feat. Post Malone)       Taylor Swift
# 12                       MILLION DOLLAR BABY      Tommy Richman
# 13                                 Like That             Future
# 14                                    Saturn                SZA
# 15                               Not Like Us     Kendrick Lamar
# 16                           Scared To Start    Michael Marcagi
# 17                                   Madonna      Natanael Cano
# 18     Igual Que Un ï¿½ï¿½ngel (with Peso Pl         Kali Uchis
# 19                                  Magnetic              ILLIT
#
#     spotify_streams
# 0         900158751
# 1         675079153
# 2         601309283
# 3         591068364
# 4         547882871
# 5         532012790
# 6         532012790
# 7         466887055
# 8         428233003
# 9         426700979
# 10        416813996
# 11        395433400
# 12        390470936
# 13        355186436
# 14        343090427
# 15        323703884
# 16        284119669
# 17        272838329
# 18        263568994
# 19        255076355

# %% [markdown]
# ##Plotting 2024 graph

# %%
fig15 = make_subplots(rows=1, cols=2, subplot_titles=('The most popular songs in 2024', 'The most popular Artists in 2024'), horizontal_spacing=0.3)

fig15.add_trace(go.Scatter(x = result2024['spotify_streams'], y = result2024['track'], mode = 'markers', name = 'Track'), row = 1, col = 1)
fig15.add_trace(go.Scatter(x = result2024['spotify_streams'], y = result2024['artist'], mode = 'markers', name = 'Artist'), row = 1, col = 2)

fig15.update_xaxes(title_text='Spotify Streams', row=1, col=1)
fig15.update_yaxes(title_text='Track', row=1, col=1)
fig15.update_xaxes(title_text='Spotify Streams', row=1, col=2)
fig15.update_yaxes(title_text='Artist', row=1, col=2)

fig15.update_layout(width=1500, height=600)
fig15.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cfd82d5b-6188-4368-a538-409ede6bbf29" class="plotly-graph-div" style="height:600px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd82d5b-6188-4368-a538-409ede6bbf29")) {                    Plotly.newPlot(                        "cfd82d5b-6188-4368-a538-409ede6bbf29",                        [{"mode":"markers","name":"Track","x":[900158751,675079153,601309283,591068364,547882871,532012790,532012790,466887055,428233003,426700979,416813996,395433400,390470936,355186436,343090427,323703884,284119669,272838329,263568994,255076355],"y":["Beautiful Things","Gata Only","i like the way you kiss me","we can't be friends (wait for your love)","Espresso","Too Sweet","Too Sweet","CARNIVAL","redrum","TEXAS HOLD 'EM","yes, and?","Fortnight (feat. Post Malone)","MILLION DOLLAR BABY","Like That","Saturn","Not Like Us","Scared To Start","Madonna","Igual Que Un \u00ef\u00bf\u00bd\u00ef\u00bf\u00bdngel (with Peso Pl","Magnetic"],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"markers","name":"Artist","x":[900158751,675079153,601309283,591068364,547882871,532012790,532012790,466887055,428233003,426700979,416813996,395433400,390470936,355186436,343090427,323703884,284119669,272838329,263568994,255076355],"y":["Benson Boone","FloyyMenor","Artemas","Ariana Grande","Sabrina Carpenter","Hozier","Hozier","\u00fd\u00fd$","21 Savage","Beyonc\u00ef\u00bf","Ariana Grande","Taylor Swift","Tommy Richman","Future","SZA","Kendrick Lamar","Michael Marcagi","Natanael Cano","Kali Uchis","ILLIT"],"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111, ...

# %% [markdown]
# We are done the individual graphs, I now want to bring them together to make a dashboard.
#
# I cant create a dash application in google colab due to their policies, so I will have to do the rest of the project externally.
#
# I will do the visualizations in either tableau or power BI instead.
